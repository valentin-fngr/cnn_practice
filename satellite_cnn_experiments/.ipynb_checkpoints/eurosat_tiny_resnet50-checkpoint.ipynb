# %%
import tensorflow as tf 
import tensorflow_datasets as tfds
import numpy as np 
import matplotlib.pyplot as plt
import datetime


# %load_ext tensorboard

# %%
dataset = tfds.load("eurosat", split="train[25%:75%]")

# %%
train_size = int(0.9 * len(dataset))
val_size = int(0.05 * len(dataset))
test_size = int(0.05 * len(dataset))

dataset = dataset.shuffle(len(dataset))
train_dataset = dataset.take(train_size)
test_dataset = dataset.skip(train_size)
val_dataset = test_dataset.skip(test_size)
test_dataset = test_dataset.take(test_size)

# %%
print("train size", train_size) 
print("val size", val_size) 
print("test size", test_size)
# Out:
# train size 12150
# val size 675
# test size 675

# %% [markdown]
# ## settings

# %%
IMAGE_SIZE = (64,64,3) 

LABELS = [
    'AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial',
    'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake'
]
BATCH_SIZE = 16
EPOCHS = 100
TEST_SIZE = 0.18
LR = 0.001

# %% [markdown]
# ### exploring the dataset

# %%
plt.figure(figsize=(10, 10))
for i,sample in enumerate(test_dataset.take(9)):
    image = sample["image"] 
    label = sample["label"]
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("uint8"))
    plt.title(LABELS[int(label)])
    plt.axis("off")

# %%
def count_classes(dataset): 
    count = {} 
    for sample in dataset: 
        label = sample["label"].numpy()
        
        if label in count: 
            count[label] += 1
        else: 
            count[label] = 1
    print
    return count

# %%
sorted_labels = sorted(LABELS)
def plot_counts(): 
    f, ax = plt.subplots(3,1, figsize=(20,10))
    
    for i,dataset in enumerate([train_dataset, test_dataset, val_dataset]): 
        count = count_classes(dataset)
        count_sorted = {key:count[key] for key in sorted(count)}
        labels = [LABELS[key] for key in count_sorted.keys()]
        ax[i].bar(height=count_sorted.values(), x=labels)
        ax[i].set_title(f"class distribution for dataset {i}")

# %%
plot_counts()

# %% [markdown]
# ### Tiny Resnet50
#
# <ul>
#     <li>We  perform  downsampling  directly  byconvolutional layers that have a stride of <strong>2</strong></li>
# </ul>

# %%
def data_augmentation(): 
    
    inputs = tf.keras.Input(shape=IMAGE_SIZE)
    x = inputs
    x = tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical")(x)
    x = tf.keras.layers.experimental.preprocessing.RandomRotation(0.4)(x)
    
    return tf.keras.Model(inputs=[inputs], outputs=[x])

data_augm = data_augmentation()

# %%
def residual_block(inputs, filters, kernel_size, is_downsampled=False):
    """
        compute a complete residual block 
        Arguments: 
            inputs: an input tensor
            filters: a list of the number of filters for each conv layer 
            kernel_size: a list of kernel sizes for each conv layer
    """
    if len(filters) != len(kernel_size): 
        return None
    
    identity = inputs 
    x = inputs 
    for i in range(len(filters)): 
        if is_downsampled and i == 0: 
            x = tf.keras.layers.Conv2D(
                filters=filters[i], 
                kernel_size=kernel_size[i], 
                padding="same", 
                strides=2
            )(x)
        else: 
            x = tf.keras.layers.Conv2D(
                filters=filters[i], 
                kernel_size=kernel_size[i], 
                padding="same", 
                strides=1
            )(x)
        
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.activations.relu(x)
    if is_downsampled: 
        # we downsample the identity block by using 1x1 filters with a stride of 2
        identity = tf.keras.layers.Conv2D(filters=filters[-1], kernel_size=1, padding="same", strides=2)(identity)
    else: 
        identity = tf.keras.layers.Conv2D(filters=filters[-1], kernel_size=1, padding="same", strides=1)(identity)
    outputs = identity + x  
    outputs = tf.keras.activations.relu(outputs)
    
    return outputs


def tiny_resnet50(nb_classses, input_shape): 
    
    inputs = tf.keras.Input(shape=(64,64,3)) 
    
    x_augm = data_augm(inputs)
    
    first_conv = tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=2, padding="same")(x_augm)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(first_conv)
    
    # stacking residual blocks
    all_filters = [
        [28,28, 64], 
        [128,128,128]
    ]
    
    kernel_sizes = [1,3,1]
    
    for filters in all_filters: 
        for i in range(2): 
            if i == 0: 
                downsample = True
            else: 
                downsample = False
            
            x = residual_block(x,filters,kernel_sizes, is_downsampled=downsample)
            
    x = tf.keras.layers.Dropout(0.2)(x)
    x = tf.keras.layers.AveragePooling2D(2)(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(nb_classses)(x)
    outputs = tf.keras.activations.sigmoid(x)
    
    
    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    
    return model

# %%
resnet50 = tiny_resnet50(len(LABELS), IMAGE_SIZE)
print(IMAGE_SIZE)
# Out:
# (64, 64, 3)

# %%
resnet50.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# model (Functional)              (None, 64, 64, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        model[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 8, 28)     1820        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 8, 8, 28)     112         conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (None, 8, 8, 28)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 28)     7084        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 8, 28)     112         conv2d_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_1 (TFOpLambda)       (None, 8, 8, 28)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 64)     1856        tf.nn.relu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 8, 64)     256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 64)     4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_2 (TFOpLambda)       (None, 8, 8, 64)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 8, 8, 64)     0           conv2d_4[0][0]
#                                                                  tf.nn.relu_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_3 (TFOpLambda)       (None, 8, 8, 64)     0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 28)     1820        tf.nn.relu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 8, 28)     112         conv2d_5[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_4 (TFOpLambda)       (None, 8, 8, 28)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 28)     7084        tf.nn.relu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 28)     112         conv2d_6[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_5 (TFOpLambda)       (None, 8, 8, 28)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     1856        tf.nn.relu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 64)     256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 64)     4160        tf.nn.relu_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_6 (TFOpLambda)       (None, 8, 8, 64)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 8, 8, 64)     0           conv2d_8[0][0]
#                                                                  tf.nn.relu_6[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_7 (TFOpLambda)       (None, 8, 8, 64)     0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    8320        tf.nn.relu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, 4, 128)    512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_8 (TFOpLambda)       (None, 4, 4, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 4, 4, 128)    147584      tf.nn.relu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 128)    512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_9 (TFOpLambda)       (None, 4, 4, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 128)    16512       tf.nn.relu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 128)    8320        tf.nn.relu_7[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_10 (TFOpLambda)      (None, 4, 4, 128)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 4, 4, 128)    0           conv2d_12[0][0]
#                                                                  tf.nn.relu_10[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_11 (TFOpLambda)      (None, 4, 4, 128)    0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 128)    16512       tf.nn.relu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 4, 128)    512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_12 (TFOpLambda)      (None, 4, 4, 128)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 128)    147584      tf.nn.relu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, 4, 128)    512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_13 (TFOpLambda)      (None, 4, 4, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 128)    16512       tf.nn.relu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 128)    16512       tf.nn.relu_11[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14 (TFOpLambda)      (None, 4, 4, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 4, 4, 128)    0           conv2d_16[0][0]
#                                                                  tf.nn.relu_14[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_15 (TFOpLambda)      (None, 4, 4, 128)    0           tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 2, 2, 256)    33024       tf.nn.relu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 2, 2, 256)    1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_16 (TFOpLambda)      (None, 2, 2, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 2, 2, 256)    590080      tf.nn.relu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 2, 2, 256)    1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_17 (TFOpLambda)      (None, 2, 2, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 256)    65792       tf.nn.relu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 2, 2, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 2, 256)    33024       tf.nn.relu_15[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_18 (TFOpLambda)      (None, 2, 2, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 2, 2, 256)    0           conv2d_20[0][0]
#                                                                  tf.nn.relu_18[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_19 (TFOpLambda)      (None, 2, 2, 256)    0           tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 2, 2, 256)    65792       tf.nn.relu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 2, 2, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_20 (TFOpLambda)      (None, 2, 2, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 2, 256)    590080      tf.nn.relu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2, 2, 256)    1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_21 (TFOpLambda)      (None, 2, 2, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 256)    65792       tf.nn.relu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 2, 2, 256)    1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 2, 2, 256)    65792       tf.nn.relu_19[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_22 (TFOpLambda)      (None, 2, 2, 256)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 2, 2, 256)    0           conv2d_24[0][0]
#                                                                  tf.nn.relu_22[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_23 (TFOpLambda)      (None, 2, 2, 256)    0           tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2, 2, 256)    0           tf.nn.relu_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 256)    0           dropout[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           2570        flatten[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid (TFOpLambda)    (None, 10)           0           dense[0][0]
# ==================================================================================================
# Total params: 1,931,610
# Trainable params: 1,926,522
# Non-trainable params: 5,088
# __________________________________________________________________________________________________

# %%
def preprocess_data(sample):
    image = tf.cast(sample["image"], dtype=tf.float32)
    label = tf.one_hot(
        sample["label"], 
        depth=len(LABELS)
    )
    
    return (image, label)

# %% [markdown]
# ### Training

# %%
# lr decay 

def lrdecay(epoch, lr): 
    k = 0.02
    if epoch >= 5: 
        lr = lr * np.exp(-k*epoch) 
    return lr

# %%
log_dir = F"logs/fit/lr={LR}_decay={EPOCHS}_dropout_decay_inverted_" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

callbacks = [
    tensorboard_callback, 
    tf.keras.callbacks.ModelCheckpoint("best_model.h5",save_best_only=True, verbose=1), 
    tf.keras.callbacks.LearningRateScheduler(lrdecay, verbose=1)
]

# %% [markdown]
# ### Do not run if you've already trained the model

# %%
train_dataset = train_dataset.map(preprocess_data)
test_dataset = test_dataset.map(preprocess_data)

train_dataset = train_dataset.batch(BATCH_SIZE) 
test_dataset = test_dataset.batch(BATCH_SIZE)

train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.prefetch(tf.data.AUTOTUNE)

# %%
resnet50.compile(
    optimizer=tf.keras.optimizers.SGD(LR),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"],
)

# %%
resnet50.fit(
    train_dataset,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=callbacks,
    validation_data=test_dataset,
)
# Out:
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 760/760 [==============================] - 20s 22ms/step - loss: 1.9365 - accuracy: 0.1251 - val_loss: 1.7241 - val_accuracy: 0.2741
#
# Epoch 00001: val_loss improved from inf to 1.72410, saving model to best_model.h5
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 760/760 [==============================] - 16s 20ms/step - loss: 1.5443 - accuracy: 0.4277 - val_loss: 3.1008 - val_accuracy: 0.1333
#
# Epoch 00002: val_loss did not improve from 1.72410
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 760/760 [==============================] - 15s 20ms/step - loss: 1.3163 - accuracy: 0.5365 - val_loss: 1.6680 - val_accuracy: 0.3630
#
# Epoch 00003: val_loss improved from 1.72410 to 1.66804, saving model to best_model.h5
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 760/760 [==============================] - 15s 20ms/step - loss: 1.1908 - accuracy: 0.5747 - val_loss: 2.6627 - val_accuracy: 0.2193
#
# Epoch 00004: val_loss did not improve from 1.66804
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 760/760 [==============================] - 16s 20ms/step - loss: 1.1136 - accuracy: 0.6015 - val_loss: 2.5127 - val_accuracy: 0.2770
#
# Epoch 00005: val_loss did not improve from 1.66804
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009512294696816873.
# 760/760 [==============================] - 15s 20ms/step - loss: 1.0537 - accuracy: 0.6169 - val_loss: 1.6094 - val_accuracy: 0.4933
#
# Epoch 00006: val_loss improved from 1.66804 to 1.60936, saving model to best_model.h5
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0008958341858992775.
# 760/760 [==============================] - 15s 20ms/step - loss: 1.0011 - accuracy: 0.6384 - val_loss: 2.1254 - val_accuracy: 0.3644
#
# Epoch 00007: val_loss did not improve from 1.60936
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0008352702518466391.
# 760/760 [==============================] - 16s 20ms/step - loss: 0.9735 - accuracy: 0.6481 - val_loss: 2.0602 - val_accuracy: 0.3956
#
# Epoch 00008: val_loss did not improve from 1.60936
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0007710516413985009.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.9197 - accuracy: 0.6689 - val_loss: 1.3270 - val_accuracy: 0.5274
#
# Epoch 00009: val_loss improved from 1.60936 to 1.32701, saving model to best_model.h5
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.000704688122795985.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.8983 - accuracy: 0.6765 - val_loss: 1.3513 - val_accuracy: 0.5319
#
# Epoch 00010: val_loss did not improve from 1.32701
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0006376281939203293.
# 760/760 [==============================] - 16s 20ms/step - loss: 0.8698 - accuracy: 0.6847 - val_loss: 2.9348 - val_accuracy: 0.2622
#
# Epoch 00011: val_loss did not improve from 1.32701
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.000571209103848907.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.8432 - accuracy: 0.6991 - val_loss: 1.3567 - val_accuracy: 0.5541
#
# Epoch 00012: val_loss did not improve from 1.32701
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0005066170443196088.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.8186 - accuracy: 0.7053 - val_loss: 1.1753 - val_accuracy: 0.5926
#
# Epoch 00013: val_loss improved from 1.32701 to 1.17527, saving model to best_model.h5
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.00044485813495654503.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.8069 - accuracy: 0.7078 - val_loss: 1.1882 - val_accuracy: 0.6089
#
# Epoch 00014: val_loss did not improve from 1.17527
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.000386741079970436.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7795 - accuracy: 0.7201 - val_loss: 0.7732 - val_accuracy: 0.7067
#
# Epoch 00015: val_loss improved from 1.17527 to 0.77318, saving model to best_model.h5
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003328711242270824.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7831 - accuracy: 0.7174 - val_loss: 0.8544 - val_accuracy: 0.6785
#
# Epoch 00016: val_loss did not improve from 0.77318
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.00028365406751660433.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7653 - accuracy: 0.7271 - val_loss: 0.6724 - val_accuracy: 0.7689
#
# Epoch 00017: val_loss improved from 0.77318 to 0.67242, saving model to best_model.h5
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.00023930896797383328.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7640 - accuracy: 0.7267 - val_loss: 0.6432 - val_accuracy: 0.7822
#
# Epoch 00018: val_loss improved from 0.67242 to 0.64319, saving model to best_model.h5
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.00019988765157450547.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7499 - accuracy: 0.7268 - val_loss: 0.7891 - val_accuracy: 0.7096
#
# Epoch 00019: val_loss did not improve from 0.64319
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001652989213717878.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7531 - accuracy: 0.7299 - val_loss: 0.8029 - val_accuracy: 0.7244
#
# Epoch 00020: val_loss did not improve from 0.64319
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001353353058301557.
# 760/760 [==============================] - 16s 20ms/step - loss: 0.7372 - accuracy: 0.7358 - val_loss: 0.6818 - val_accuracy: 0.7630
#
# Epoch 00021: val_loss did not improve from 0.64319
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001097006621047156.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7365 - accuracy: 0.7320 - val_loss: 0.7203 - val_accuracy: 0.7333
#
# Epoch 00022: val_loss did not improve from 0.64319
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 8.803684235017278e-05.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7192 - accuracy: 0.7432 - val_loss: 0.8549 - val_accuracy: 0.6681
#
# Epoch 00023: val_loss did not improve from 0.64319
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.994822673301073e-05.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7245 - accuracy: 0.7411 - val_loss: 0.6818 - val_accuracy: 0.7585
#
# Epoch 00024: val_loss did not improve from 0.64319
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 5.502322352590192e-05.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7200 - accuracy: 0.7402 - val_loss: 0.5938 - val_accuracy: 0.7822
#
# Epoch 00025: val_loss improved from 0.64319 to 0.59380, saving model to best_model.h5
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 4.285213094006686e-05.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7177 - accuracy: 0.7429 - val_loss: 0.6384 - val_accuracy: 0.7659
#
# Epoch 00026: val_loss did not improve from 0.59380
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.3041203345583675e-05.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7150 - accuracy: 0.7461 - val_loss: 0.5649 - val_accuracy: 0.7985
#
# Epoch 00027: val_loss improved from 0.59380 to 0.56491, saving model to best_model.h5
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 2.5222977606161723e-05.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7135 - accuracy: 0.7481 - val_loss: 0.6223 - val_accuracy: 0.7837
# Epoch 00028: val_loss did not improve from 0.56491
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 1.9063116959727717e-05.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7081 - accuracy: 0.7462 - val_loss: 0.6858 - val_accuracy: 0.7600
#
# Epoch 00029: val_loss did not improve from 0.56491
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.4264235389007537e-05.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7061 - accuracy: 0.7442 - val_loss: 0.5976 - val_accuracy: 0.7807
#
# Epoch 00030: val_loss did not improve from 0.56491
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.0567205701571142e-05.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7036 - accuracy: 0.7457 - val_loss: 0.6333 - val_accuracy: 0.7704
#
# Epoch 00031: val_loss did not improve from 0.56491
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 7.750485163144059e-06.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7048 - accuracy: 0.7482 - val_loss: 0.5898 - val_accuracy: 0.8089
#
# Epoch 00032: val_loss did not improve from 0.56491
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 5.628007630124274e-06.
# 760/760 [==============================] - 16s 20ms/step - loss: 0.7099 - accuracy: 0.7431 - val_loss: 0.6642 - val_accuracy: 0.7719
#
# Epoch 00033: val_loss did not improve from 0.56491
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 4.046108368039099e-06.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7130 - accuracy: 0.7432 - val_loss: 0.6302 - val_accuracy: 0.7719
#
# Epoch 00034: val_loss did not improve from 0.56491
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 2.8798997309403605e-06.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7093 - accuracy: 0.7491 - val_loss: 0.5820 - val_accuracy: 0.7926
#
# Epoch 00035: val_loss did not improve from 0.56491
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 2.029431045747336e-06.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7057 - accuracy: 0.7443 - val_loss: 0.7057 - val_accuracy: 0.7422
#
# Epoch 00036: val_loss did not improve from 0.56491
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 1.415885975345514e-06.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7040 - accuracy: 0.7495 - val_loss: 0.6786 - val_accuracy: 0.7659
#
# Epoch 00037: val_loss did not improve from 0.56491
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 9.780010712296683e-07.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7056 - accuracy: 0.7448 - val_loss: 0.7025 - val_accuracy: 0.7585
#
# Epoch 00038: val_loss did not improve from 0.56491
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.688171598117722e-07.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7075 - accuracy: 0.7488 - val_loss: 0.6888 - val_accuracy: 0.7348
#
# Epoch 00039: val_loss did not improve from 0.56491
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 4.528272594849868e-07.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7129 - accuracy: 0.7444 - val_loss: 0.6189 - val_accuracy: 0.7793
#
# Epoch 00040: val_loss did not improve from 0.56491
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 3.0353919343099844e-07.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7147 - accuracy: 0.7415 - val_loss: 0.6502 - val_accuracy: 0.7674
#
# Epoch 00041: val_loss did not improve from 0.56491
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.0144386305716093e-07.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7120 - accuracy: 0.7455 - val_loss: 0.6740 - val_accuracy: 0.7689
#
# Epoch 00042: val_loss did not improve from 0.56491
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 1.3235805271504836e-07.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7115 - accuracy: 0.7461 - val_loss: 0.6452 - val_accuracy: 0.7778
#
# Epoch 00043: val_loss did not improve from 0.56491
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 8.61001175006586e-08.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7074 - accuracy: 0.7430 - val_loss: 0.5813 - val_accuracy: 0.7985
#
# Epoch 00044: val_loss did not improve from 0.56491
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 5.545161022968771e-08.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.6964 - accuracy: 0.7505 - val_loss: 0.6601 - val_accuracy: 0.7763
#
# Epoch 00045: val_loss did not improve from 0.56491
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 3.535750841939908e-08.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7121 - accuracy: 0.7444 - val_loss: 0.5997 - val_accuracy: 0.7852
#
# Epoch 00046: val_loss did not improve from 0.56491
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.2320617127501258e-08.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7179 - accuracy: 0.7407 - val_loss: 0.6209 - val_accuracy: 0.7719
#
# Epoch 00047: val_loss did not improve from 0.56491
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 1.3950435920862897e-08.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7059 - accuracy: 0.7422 - val_loss: 0.6173 - val_accuracy: 0.7748
#
# Epoch 00048: val_loss did not improve from 0.56491
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 8.632298329039874e-09.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7042 - accuracy: 0.7458 - val_loss: 0.6107 - val_accuracy: 0.7778
#
# Epoch 00049: val_loss did not improve from 0.56491
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 5.288373861687865e-09.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7165 - accuracy: 0.7380 - val_loss: 0.5878 - val_accuracy: 0.7926
#
# Epoch 00050: val_loss did not improve from 0.56491
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 3.207560812674648e-09.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7024 - accuracy: 0.7502 - val_loss: 0.6759 - val_accuracy: 0.7659
#
# Epoch 00051: val_loss did not improve from 0.56491
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.926126129353079e-09.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7011 - accuracy: 0.7488 - val_loss: 0.6302 - val_accuracy: 0.7733
#
# Epoch 00052: val_loss did not improve from 0.56491
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.1451215726516747e-09.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7081 - accuracy: 0.7437 - val_loss: 0.6629 - val_accuracy: 0.7600
#
# Epoch 00053: val_loss did not improve from 0.56491
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 6.740242370620105e-10.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7076 - accuracy: 0.7465 - val_loss: 0.6255 - val_accuracy: 0.7852
#
# Epoch 00054: val_loss did not improve from 0.56491
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 3.9278643936427697e-10.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7118 - accuracy: 0.7470 - val_loss: 0.6800 - val_accuracy: 0.7644
#
# Epoch 00055: val_loss did not improve from 0.56491
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 2.2661806338214833e-10.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7180 - accuracy: 0.7451 - val_loss: 0.6810 - val_accuracy: 0.7644
#
# Epoch 00056: val_loss did not improve from 0.56491
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.2944628856301964e-10.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7129 - accuracy: 0.7433 - val_loss: 0.6622 - val_accuracy: 0.7793
# Epoch 00057: val_loss did not improve from 0.56491
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 7.320516825654791e-11.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7100 - accuracy: 0.7416 - val_loss: 0.6755 - val_accuracy: 0.7541
#
# Epoch 00058: val_loss did not improve from 0.56491
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 4.0987455718362046e-11.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7039 - accuracy: 0.7495 - val_loss: 0.5604 - val_accuracy: 0.8015
#
# Epoch 00059: val_loss improved from 0.56491 to 0.56042, saving model to best_model.h5
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 2.27204654611702e-11.
# 760/760 [==============================] - 16s 20ms/step - loss: 0.7076 - accuracy: 0.7467 - val_loss: 0.6902 - val_accuracy: 0.7689
#
# Epoch 00060: val_loss did not improve from 0.56042
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1.2469256191543277e-11.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7053 - accuracy: 0.7446 - val_loss: 0.6685 - val_accuracy: 0.7674
#
# Epoch 00061: val_loss did not improve from 0.56042
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 6.775181372337229e-12.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7044 - accuracy: 0.7446 - val_loss: 0.6066 - val_accuracy: 0.7837
#
# Epoch 00062: val_loss did not improve from 0.56042
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 3.644671225432132e-12.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7015 - accuracy: 0.7464 - val_loss: 0.6113 - val_accuracy: 0.7837
#
# Epoch 00063: val_loss did not improve from 0.56042
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1.9411220891661313e-12.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7033 - accuracy: 0.7487 - val_loss: 0.6387 - val_accuracy: 0.7644
#
# Epoch 00064: val_loss did not improve from 0.56042
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1.0235390176475408e-12.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.6988 - accuracy: 0.7497 - val_loss: 0.5904 - val_accuracy: 0.7793
#
# Epoch 00065: val_loss did not improve from 0.56042
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 5.343342127965613e-13.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7026 - accuracy: 0.7477 - val_loss: 0.6321 - val_accuracy: 0.7793
#
# Epoch 00066: val_loss did not improve from 0.56042
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.7617133768770047e-13.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7151 - accuracy: 0.7467 - val_loss: 0.6736 - val_accuracy: 0.7556
#
# Epoch 00067: val_loss did not improve from 0.56042
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1.413192427992174e-13.
# 760/760 [==============================] - 16s 20ms/step - loss: 0.7014 - accuracy: 0.7472 - val_loss: 0.6894 - val_accuracy: 0.7481
#
# Epoch 00068: val_loss did not improve from 0.56042
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 7.159473237015662e-14.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7107 - accuracy: 0.7456 - val_loss: 0.6489 - val_accuracy: 0.7689
#
# Epoch 00069: val_loss did not improve from 0.56042
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 3.5910205650054357e-14.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7044 - accuracy: 0.7465 - val_loss: 0.6832 - val_accuracy: 0.7526
#
# Epoch 00070: val_loss did not improve from 0.56042
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.783248042876255e-14.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7143 - accuracy: 0.7444 - val_loss: 0.6234 - val_accuracy: 0.7793
#
# Epoch 00071: val_loss did not improve from 0.56042
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 8.767235124856722e-15.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7120 - accuracy: 0.7396 - val_loss: 0.6561 - val_accuracy: 0.7600
#
# Epoch 00072: val_loss did not improve from 0.56042
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 4.267471341450228e-15.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7139 - accuracy: 0.7447 - val_loss: 0.6364 - val_accuracy: 0.7615
#
# Epoch 00073: val_loss did not improve from 0.56042
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 2.056532842208945e-15.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7093 - accuracy: 0.7440 - val_loss: 0.5978 - val_accuracy: 0.7881
#
# Epoch 00074: val_loss did not improve from 0.56042
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 9.812004604898355e-16.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7045 - accuracy: 0.7466 - val_loss: 0.6500 - val_accuracy: 0.7763
#
# Epoch 00075: val_loss did not improve from 0.56042
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 4.634862623055234e-16.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7088 - accuracy: 0.7449 - val_loss: 0.6097 - val_accuracy: 0.7970
#
# Epoch 00076: val_loss did not improve from 0.56042
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 2.1675696521308048e-16.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7136 - accuracy: 0.7442 - val_loss: 0.6327 - val_accuracy: 0.7793
#
# Epoch 00077: val_loss did not improve from 0.56042
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.0036130607526066e-16.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7014 - accuracy: 0.7474 - val_loss: 0.6643 - val_accuracy: 0.7689
#
# Epoch 00078: val_loss did not improve from 0.56042
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 4.6006226688119846e-17.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.6993 - accuracy: 0.7486 - val_loss: 0.6706 - val_accuracy: 0.7467
#
# Epoch 00079: val_loss did not improve from 0.56042
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 2.0879686793402047e-17.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7136 - accuracy: 0.7407 - val_loss: 0.6245 - val_accuracy: 0.7659
#
# Epoch 00080: val_loss did not improve from 0.56042
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 9.38184786327972e-18.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7074 - accuracy: 0.7479 - val_loss: 0.7021 - val_accuracy: 0.7407
#
# Epoch 00081: val_loss did not improve from 0.56042
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 4.173590654776649e-18.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7132 - accuracy: 0.7415 - val_loss: 0.5648 - val_accuracy: 0.7896
#
# Epoch 00082: val_loss did not improve from 0.56042
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 1.8381814361985857e-18.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7153 - accuracy: 0.7448 - val_loss: 0.6389 - val_accuracy: 0.7748
#
# Epoch 00083: val_loss did not improve from 0.56042
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 8.015377036158956e-19.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7039 - accuracy: 0.7465 - val_loss: 0.6419 - val_accuracy: 0.7674
#
# Epoch 00084: val_loss did not improve from 0.56042
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 3.4603226147050338e-19.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7058 - accuracy: 0.7475 - val_loss: 0.5580 - val_accuracy: 0.7970
#
# Epoch 00085: val_loss improved from 0.56042 to 0.55797, saving model to best_model.h5
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 1.4789935847196477e-19.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7111 - accuracy: 0.7408 - val_loss: 0.5669 - val_accuracy: 0.7956
#
# Epoch 00086: val_loss did not improve from 0.55797
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.25854026794821e-20.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7031 - accuracy: 0.7486 - val_loss: 0.6166 - val_accuracy: 0.7719
#
# Epoch 00087: val_loss did not improve from 0.55797
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 2.6220251463035038e-20.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7190 - accuracy: 0.7438 - val_loss: 0.6842 - val_accuracy: 0.7630
#
# Epoch 00088: val_loss did not improve from 0.55797
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 1.0875712539628023e-20.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7085 - accuracy: 0.7477 - val_loss: 0.6214 - val_accuracy: 0.7719
#
# Epoch 00089: val_loss did not improve from 0.55797
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 4.466173916838302e-21.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7031 - accuracy: 0.7494 - val_loss: 0.5950 - val_accuracy: 0.7896
#
# Epoch 00090: val_loss did not improve from 0.55797
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 1.8158108050916215e-21.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7075 - accuracy: 0.7444 - val_loss: 0.6040 - val_accuracy: 0.7941
#
# Epoch 00091: val_loss did not improve from 0.55797
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 7.309078680254096e-22.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7117 - accuracy: 0.7443 - val_loss: 0.6048 - val_accuracy: 0.7881
#
# Epoch 00092: val_loss did not improve from 0.55797
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.9128070595173993e-22.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7071 - accuracy: 0.7468 - val_loss: 0.6211 - val_accuracy: 0.7911
#
# Epoch 00093: val_loss did not improve from 0.55797
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 1.1492588773298754e-22.
# 760/760 [==============================] - 15s 20ms/step - loss: 0.7052 - accuracy: 0.7453 - val_loss: 0.6691 - val_accuracy: 0.7689
#
# Epoch 00094: val_loss did not improve from 0.55797
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 4.489325119353284e-23.
# 760/760 [==============================] - 16s 20ms/step - loss: 0.6992 - accuracy: 0.7473 - val_loss: 0.6940 - val_accuracy: 0.7526
#
# Epoch 00095: val_loss did not improve from 0.55797
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 1.736206166210519e-23.
# 760/760 [==============================] - 16s 20ms/step - loss: 0.7114 - accuracy: 0.7467 - val_loss: 0.5585 - val_accuracy: 0.8000
#
# Epoch 00096: val_loss did not improve from 0.55797
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 6.647809930362375e-24.
# 760/760 [==============================] - 16s 20ms/step - loss: 0.7090 - accuracy: 0.7474 - val_loss: 0.6349 - val_accuracy: 0.7644
#
# Epoch 00097: val_loss did not improve from 0.55797
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.5200719108451475e-24.
# 760/760 [==============================] - 16s 20ms/step - loss: 0.7167 - accuracy: 0.7449 - val_loss: 0.6061 - val_accuracy: 0.7867
#
# Epoch 00098: val_loss did not improve from 0.55797
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 9.458109816105304e-25.
# 760/760 [==============================] - 16s 21ms/step - loss: 0.7108 - accuracy: 0.7433 - val_loss: 0.5971 - val_accuracy: 0.7704
#
# Epoch 00099: val_loss did not improve from 0.55797
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 3.514413197036425e-25.
# 760/760 [==============================] - 17s 23ms/step - loss: 0.7060 - accuracy: 0.7451 - val_loss: 0.7126 - val_accuracy: 0.7437
#
# Epoch 00100: val_loss did not improve from 0.55797

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6007 (pid 7453), started 8:53:53 ago. (Use '!kill 7453' to kill it.)
#       <iframe id="tensorboard-frame-b184098a85181ac7" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b184098a85181ac7");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Observations of the naïve resnet50 model
#
# ### The model is overfitting with basic data augm, lr=0.01, no dropout
#
# <p>Possible solutions for this problem</p>
#
# <ol>
#     <li>More data</li>
#     <li>Adding Data Augmentation </li>
#     <li>Adding regularization (Lr decay, Dropout)</li>
#     <li>Reduce complexity</li>
# </ol>

# %% [markdown]
# ### Let's test our model

# %%
resnet50 = tiny_resnet50(len(LABELS), IMAGE_SIZE)
resnet50.load_weights("best_model.h5")

# %%
def get_true_label(image, label): 
    return tf.math.argmax(label)

# %%
val_dataset = val_dataset.map(preprocess_data)

# %%
val_images = []
val_labels = [] 

for sample in list(val_dataset.as_numpy_iterator()): 
    val_images.append(sample[0]) 
    val_labels.append(sample[1])
    
    plt.imshow(sample[0].astype("uint8"))
    print(LABELS[np.argmax(sample[1])])
# Out:
# HerbaceousVegetation
# Pasture
# AnnualCrop
# Forest
# PermanentCrop
# AnnualCrop
# Pasture
# Residential
# Industrial
# SeaLake
# SeaLake
# River
# Industrial
# Residential
# Industrial
# AnnualCrop
# River
# Industrial
# HerbaceousVegetation
# Highway
# Forest
# Industrial
# Forest
# River
# Industrial
# Residential
# Forest
# Highway
# Pasture
# Forest
# PermanentCrop
# AnnualCrop
# Pasture
# Industrial
# Industrial
# River
# Residential
# River
# River
# PermanentCrop
# River
# PermanentCrop
# Residential
# Highway
# Residential
# AnnualCrop
# AnnualCrop
# Industrial
# Pasture
# River
# Residential
# Industrial
# Highway
# SeaLake
# River
# HerbaceousVegetation
# River
# Highway
# Highway
# River
# Forest
# River
# Forest
# SeaLake
# AnnualCrop
# HerbaceousVegetation
# Highway
# Highway
# Industrial
# PermanentCrop
# Highway
# Pasture
# Industrial
# Forest
# PermanentCrop
# River
# HerbaceousVegetation
# HerbaceousVegetation
# Forest
# Industrial
# Pasture
# AnnualCrop
# Forest
# SeaLake
# Highway
# HerbaceousVegetation
# AnnualCrop
# PermanentCrop
# HerbaceousVegetation
# PermanentCrop
# Highway
# River
# AnnualCrop
# HerbaceousVegetation
# Residential
# SeaLake
# AnnualCrop
# Forest
# PermanentCrop
# Industrial
# AnnualCrop
# Pasture
# AnnualCrop
# HerbaceousVegetation
# PermanentCrop
# AnnualCrop
# AnnualCrop
# Forest
# HerbaceousVegetation
# AnnualCrop
# Forest
# Highway
# Forest
# AnnualCrop
# Residential
# Residential
# Highway
# Forest
# SeaLake
# SeaLake
# HerbaceousVegetation
# Industrial
# SeaLake
# Residential
# Industrial
# Forest
# Industrial
# Forest
# Residential
# SeaLake
# Residential
# SeaLake
# Forest
# Residential
# Pasture
# SeaLake
# SeaLake
# Residential
# Forest
# Pasture
# Highway
# Forest
# AnnualCrop
# HerbaceousVegetation
# Pasture
# SeaLake
# River
# Residential
# Forest
# HerbaceousVegetation
# Highway
# HerbaceousVegetation
# Highway
# SeaLake
# Residential
# River
# PermanentCrop
# Industrial
# Industrial
# Highway
# River
# SeaLake
# Residential
# River
# HerbaceousVegetation
# AnnualCrop
# HerbaceousVegetation
# SeaLake
# Residential
# Industrial
# Industrial
# HerbaceousVegetation
# Industrial
# Forest
# SeaLake
# Forest
# River
# SeaLake
# Pasture
# SeaLake
# HerbaceousVegetation
# SeaLake
# HerbaceousVegetation
# Residential
# PermanentCrop
# PermanentCrop
# Industrial
# AnnualCrop
# Pasture
# Pasture
# Industrial
# Highway
# Pasture
# Industrial
# Highway
# HerbaceousVegetation
# Residential
# Forest
# PermanentCrop
# AnnualCrop
# SeaLake
# Industrial
# Industrial
# SeaLake
# PermanentCrop
# SeaLake
# AnnualCrop
# HerbaceousVegetation
# SeaLake
# Residential
# Highway
# Residential
# Forest
# AnnualCrop
# HerbaceousVegetation
# AnnualCrop
# Industrial
# PermanentCrop
# Forest
# Highway
# River
# AnnualCrop
# HerbaceousVegetation
# Pasture
# HerbaceousVegetation
# SeaLake
# Industrial
# Forest
# SeaLake
# River
# Forest
# Residential
# Industrial
# HerbaceousVegetation
# Highway
# Industrial
# Forest
# AnnualCrop
# River
# Industrial
# Industrial
# River
# River
# Highway
# River
# HerbaceousVegetation
# Forest
# HerbaceousVegetation
# Pasture
# Pasture
# SeaLake
# AnnualCrop
# Highway
# AnnualCrop
# Pasture
# Residential
# SeaLake
# AnnualCrop
# HerbaceousVegetation
# River
# Residential
# Industrial
# AnnualCrop
# SeaLake
# Industrial
# Highway
# Pasture
# Residential
# PermanentCrop
# Residential
# SeaLake
# Industrial
# PermanentCrop
# River
# Forest
# SeaLake
# PermanentCrop
# HerbaceousVegetation
# Residential
# SeaLake
# Forest
# Pasture
# HerbaceousVegetation
# Industrial
# SeaLake
# SeaLake
# Highway
# PermanentCrop
# Forest
# Highway
# Forest
# HerbaceousVegetation
# AnnualCrop
# Highway
# SeaLake
# Forest
# Highway
# Forest
# Residential
# Industrial
# PermanentCrop
# River
# AnnualCrop
# PermanentCrop
# AnnualCrop
# River
# River
# SeaLake
# Pasture
# Industrial
# SeaLake
# Residential
# Residential
# AnnualCrop
# Forest
# AnnualCrop
# SeaLake
# Residential
# PermanentCrop
# Highway
# River
# HerbaceousVegetation
# AnnualCrop
# AnnualCrop
# Forest
# Forest
# PermanentCrop
# Residential
# River
# Pasture
# AnnualCrop
# Forest
# Highway
# AnnualCrop
# HerbaceousVegetation
# AnnualCrop
# AnnualCrop
# AnnualCrop
# River
# HerbaceousVegetation
# River
# Highway
# Residential
# SeaLake
# SeaLake
# Industrial
# Forest
# HerbaceousVegetation
# HerbaceousVegetation
# Forest
# Pasture
# Industrial
# SeaLake
# AnnualCrop
# SeaLake
# HerbaceousVegetation
# Pasture
# Highway
# Residential
# SeaLake
# River
# HerbaceousVegetation
# PermanentCrop
# Forest
# AnnualCrop
# Residential
# AnnualCrop
# AnnualCrop
# Residential
# AnnualCrop
# Industrial
# Pasture
# Highway
# Forest
# Industrial
# PermanentCrop
# Highway
# Pasture
# Industrial
# River
# River
# HerbaceousVegetation
# Residential
# AnnualCrop
# Pasture
# Residential
# SeaLake
# AnnualCrop
# Highway
# SeaLake
# Highway
# Highway
# PermanentCrop
# Industrial
# Residential
# River
# Industrial
# Industrial
# AnnualCrop
# Residential
# Residential
# PermanentCrop
# PermanentCrop
# Forest
# Pasture
# SeaLake
# Residential
# River
# PermanentCrop
# Pasture
# Industrial
# SeaLake
# HerbaceousVegetation
# Industrial
# HerbaceousVegetation
# AnnualCrop
# HerbaceousVegetation
# River
# SeaLake
# Forest
# Forest
# AnnualCrop
# SeaLake
# Forest
# Forest
# SeaLake
# Industrial
# HerbaceousVegetation
# River
# Forest
# Industrial
# Industrial
# HerbaceousVegetation
# Highway
# AnnualCrop
# River
# SeaLake
# Residential
# Forest
# SeaLake
# Forest
# SeaLake
# AnnualCrop
# Forest
# Pasture
# Highway
# River
# Pasture
# Residential
# PermanentCrop
# Highway
# Highway
# SeaLake
# HerbaceousVegetation
# Forest
# SeaLake
# Residential
# SeaLake
# HerbaceousVegetation
# Pasture
# River
# Residential
# Highway
# Industrial
# Industrial
# SeaLake
# Residential
# Residential
# Residential
# PermanentCrop
# Highway
# River
# Residential
# PermanentCrop
# AnnualCrop
# HerbaceousVegetation
# Residential
# River
# SeaLake
# Pasture
# SeaLake
# River
# AnnualCrop
# Residential
# AnnualCrop
# SeaLake
# SeaLake
# PermanentCrop
# Pasture
# Forest
# HerbaceousVegetation
# AnnualCrop
# AnnualCrop
# Highway
# PermanentCrop
# AnnualCrop
# Residential
# AnnualCrop
# Highway
# SeaLake
# Industrial
# Highway
# Industrial
# Residential
# HerbaceousVegetation
# HerbaceousVegetation
# Industrial
# PermanentCrop
# PermanentCrop
# AnnualCrop
# Highway
# PermanentCrop
# Pasture
# Industrial
# River
# Highway
# AnnualCrop
# River
# Residential
# Pasture
# River
# HerbaceousVegetation
# PermanentCrop
# SeaLake
# Industrial
# AnnualCrop
# AnnualCrop
# PermanentCrop
# Residential
# PermanentCrop
# Industrial
# HerbaceousVegetation
# Highway
# PermanentCrop
# Forest
# Highway
# Pasture
# Highway
# Forest
# Residential
# PermanentCrop
# HerbaceousVegetation
# Residential
# Residential
# Pasture
# River
# Highway
# Forest
# HerbaceousVegetation
# Industrial
# River
# AnnualCrop
# Industrial
# Forest
# Forest
# Highway
# Highway
# AnnualCrop
# River
# Industrial
# Industrial
# Pasture
# SeaLake
# SeaLake
# River
# AnnualCrop
# Industrial
# Pasture
# PermanentCrop
# HerbaceousVegetation
# HerbaceousVegetation
# HerbaceousVegetation
# Highway
# River
# Residential
# River
# HerbaceousVegetation
# Industrial
# Highway
# River
# Forest
# SeaLake
# PermanentCrop
# PermanentCrop
# HerbaceousVegetation
# SeaLake
# HerbaceousVegetation
# Residential
# Industrial
# Residential
# Pasture
# Industrial
# AnnualCrop
# PermanentCrop
# Highway
# Highway
# Residential
# Residential
# SeaLake
# PermanentCrop
# Forest
# River
# Forest
# Residential
# Residential
# SeaLake
# Highway
# SeaLake
# Residential
# Residential
# Highway
# Industrial
# Pasture
# Forest
# Industrial
# AnnualCrop
# AnnualCrop
# River
# HerbaceousVegetation
# Industrial
# Forest
# Industrial
# SeaLake
# Residential
# Pasture
# AnnualCrop
# Residential
# SeaLake
# Forest
# SeaLake
# Forest
# Pasture
# Highway
# Pasture
# PermanentCrop
# AnnualCrop
# Industrial
# Industrial
# HerbaceousVegetation
# Highway
# Forest
# River
# River
# HerbaceousVegetation
# Industrial
# SeaLake
# AnnualCrop
# HerbaceousVegetation
# HerbaceousVegetation
# SeaLake
# River
# AnnualCrop
# AnnualCrop
# Highway
# AnnualCrop
# Highway
# Forest
# Industrial
# PermanentCrop
# PermanentCrop
# HerbaceousVegetation
# Pasture
# AnnualCrop
# PermanentCrop
# River
# Forest
# Highway
# SeaLake
# Pasture
# Forest
# SeaLake
# PermanentCrop
# Industrial
# Industrial
# HerbaceousVegetation

# %%
np.array(val_images).shape
# Out:
# (675, 64, 64, 3)

# %%
probs = resnet50.predict(np.array(val_images))
preds = np.argmax(probs, axis=-1)
print(preds)
# Out:
# [2 5 0 1 6 3 5 7 4 9 9 1 4 7 4 0 3 4 2 7 1 4 1 0 4 7 1 4 5 1 6 0 2 4 4 8 7
#  8 8 6 8 6 7 4 7 0 0 4 5 3 7 4 7 9 6 1 8 7 5 3 2 8 1 9 5 7 3 5 4 6 6 2 4 1
#  6 8 2 8 1 4 5 2 1 9 5 2 0 0 2 2 3 3 0 1 7 9 0 1 6 4 1 5 0 2 2 0 0 1 6 0 1
#  2 1 0 7 7 6 1 1 9 2 4 9 7 4 1 4 1 4 9 7 9 1 7 5 9 1 7 1 5 3 1 0 2 5 9 8 7
#  1 2 3 7 7 9 7 8 6 4 4 8 8 9 7 8 2 0 2 1 7 4 4 2 4 1 9 1 3 9 5 9 2 9 2 7 6
#  6 4 6 3 1 4 5 3 4 3 2 7 1 2 5 9 4 4 9 2 9 0 2 9 7 3 7 1 6 2 0 7 7 1 3 7 0
#  2 6 7 9 4 1 9 8 1 7 4 2 0 4 2 0 3 4 4 8 3 8 8 3 1 2 5 5 9 0 3 0 5 7 9 0 2
#  8 7 4 0 9 4 8 5 7 6 4 9 4 6 4 1 9 6 7 7 9 1 5 2 4 9 9 7 6 1 3 1 7 0 2 9 1
#  3 1 7 4 6 3 0 3 6 6 8 9 5 4 9 7 7 0 1 0 9 7 6 3 8 2 8 0 1 1 6 7 8 5 0 1 8
#  0 7 0 0 5 8 2 8 7 7 9 9 4 1 2 3 1 5 4 9 3 9 4 6 3 4 9 8 7 6 1 0 7 0 2 7 0
#  4 5 3 1 4 2 7 5 4 8 8 2 7 0 5 7 9 0 3 9 8 3 2 4 7 8 7 4 0 7 7 6 2 1 6 9 7
#  8 7 5 4 9 2 4 1 0 2 8 9 1 2 0 9 1 1 9 4 7 8 1 4 4 2 7 0 8 9 7 1 9 1 9 0 1
#  5 3 3 5 7 6 8 3 9 6 1 9 7 9 1 6 8 7 3 4 4 9 7 7 7 6 3 8 7 6 0 1 7 8 9 5 9
#  8 0 7 0 9 9 7 5 1 7 0 0 3 2 0 7 5 6 9 4 5 4 7 7 2 4 6 6 6 3 6 5 7 8 3 5 5
#  7 5 3 6 6 9 4 0 3 2 7 3 4 2 3 6 1 3 5 3 1 7 4 2 7 7 5 8 3 1 2 4 8 2 4 1 1
#  2 3 0 2 4 4 3 9 9 8 0 4 5 6 2 7 2 3 8 7 8 2 4 8 8 1 9 3 7 2 9 3 7 4 7 5 4
#  0 6 3 7 7 7 9 6 1 4 1 7 7 1 0 9 7 7 2 4 5 1 4 0 0 3 2 4 1 4 9 7 5 0 7 9 1
#  9 1 5 3 8 6 0 4 4 2 3 1 8 8 2 4 9 0 6 6 9 8 0 0 8 0 6 1 4 6 6 2 5 6 6 8 1
#  3 9 8 1 5 6 7 4 2]

# %%
true_label = np.argmax(val_labels, axis=-1)
true_label
# Out:
# array([2, 5, 0, 1, 6, 0, 5, 7, 4, 9, 9, 8, 4, 7, 4, 0, 8, 4, 2, 3, 1, 4,
#        1, 8, 4, 7, 1, 3, 5, 1, 6, 0, 5, 4, 4, 8, 7, 8, 8, 6, 8, 6, 7, 3,
#        7, 0, 0, 4, 5, 8, 7, 4, 3, 9, 8, 2, 8, 3, 3, 8, 1, 8, 1, 9, 0, 2,
#        3, 3, 4, 6, 3, 5, 4, 1, 6, 8, 2, 2, 1, 4, 5, 0, 1, 9, 3, 2, 0, 6,
#        2, 6, 3, 8, 0, 2, 7, 9, 0, 1, 6, 4, 0, 5, 0, 2, 6, 0, 0, 1, 2, 0,
#        1, 3, 1, 0, 7, 7, 3, 1, 9, 9, 2, 4, 9, 7, 4, 1, 4, 1, 7, 9, 7, 9,
#        1, 7, 5, 9, 9, 7, 1, 5, 3, 1, 0, 2, 5, 9, 8, 7, 1, 2, 3, 2, 3, 9,
#        7, 8, 6, 4, 4, 3, 8, 9, 7, 8, 2, 0, 2, 9, 7, 4, 4, 2, 4, 1, 9, 1,
#        8, 9, 5, 9, 2, 9, 2, 7, 6, 6, 4, 0, 5, 5, 4, 3, 5, 4, 3, 2, 7, 1,
#        6, 0, 9, 4, 4, 9, 6, 9, 0, 2, 9, 7, 3, 7, 1, 0, 2, 0, 4, 6, 1, 3,
#        8, 0, 2, 5, 2, 9, 4, 1, 9, 8, 1, 7, 4, 2, 3, 4, 1, 0, 8, 4, 4, 8,
#        8, 3, 8, 2, 1, 2, 5, 5, 9, 0, 3, 0, 5, 7, 9, 0, 2, 8, 7, 4, 0, 9,
#        4, 3, 5, 7, 6, 7, 9, 4, 6, 8, 1, 9, 6, 2, 7, 9, 1, 5, 2, 4, 9, 9,
#        3, 6, 1, 3, 1, 2, 0, 3, 9, 1, 3, 1, 7, 4, 6, 8, 0, 6, 0, 8, 8, 9,
#        5, 4, 9, 7, 7, 0, 1, 0, 9, 7, 6, 3, 8, 2, 0, 0, 1, 1, 6, 7, 8, 5,
#        0, 1, 3, 0, 2, 0, 0, 0, 8, 2, 8, 3, 7, 9, 9, 4, 1, 2, 2, 1, 5, 4,
#        9, 0, 9, 2, 5, 3, 7, 9, 8, 2, 6, 1, 0, 7, 0, 0, 7, 0, 4, 5, 3, 1,
#        4, 6, 3, 5, 4, 8, 8, 2, 7, 0, 5, 7, 9, 0, 3, 9, 3, 3, 6, 4, 7, 8,
#        4, 4, 0, 7, 7, 6, 6, 1, 5, 9, 7, 8, 6, 5, 4, 9, 2, 4, 2, 0, 2, 8,
#        9, 1, 1, 0, 9, 1, 1, 9, 4, 2, 8, 1, 4, 4, 2, 3, 0, 8, 9, 7, 1, 9,
#        1, 9, 0, 1, 5, 3, 8, 5, 7, 6, 3, 3, 9, 2, 1, 9, 7, 9, 2, 5, 8, 7,
#        3, 4, 4, 9, 7, 7, 7, 6, 3, 8, 7, 6, 0, 2, 7, 8, 9, 5, 9, 8, 0, 7,
#        0, 9, 9, 6, 5, 1, 2, 0, 0, 3, 6, 0, 7, 0, 3, 9, 4, 3, 4, 7, 2, 2,
#        4, 6, 6, 0, 3, 6, 5, 4, 8, 3, 0, 8, 7, 5, 8, 2, 6, 9, 4, 0, 0, 6,
#        7, 6, 4, 2, 3, 6, 1, 3, 5, 3, 1, 7, 6, 2, 7, 7, 5, 8, 3, 1, 2, 4,
#        8, 0, 4, 1, 1, 3, 3, 0, 8, 4, 4, 5, 9, 9, 8, 0, 4, 5, 6, 2, 2, 2,
#        3, 8, 7, 8, 2, 4, 3, 8, 1, 9, 6, 6, 2, 9, 2, 7, 4, 7, 5, 4, 0, 6,
#        3, 3, 7, 7, 9, 6, 1, 8, 1, 7, 7, 9, 3, 9, 7, 7, 3, 4, 5, 1, 4, 0,
#        0, 8, 2, 4, 1, 4, 9, 7, 5, 0, 7, 9, 1, 9, 1, 5, 3, 5, 6, 0, 4, 4,
#        2, 3, 1, 8, 8, 2, 4, 9, 0, 2, 2, 9, 8, 0, 0, 3, 0, 3, 1, 4, 6, 6,
#        2, 5, 0, 6, 8, 1, 3, 9, 5, 1, 9, 6, 4, 4, 2])

# %%
print(len(predictions))
print(len(true_label))
# Out:
# 675
# 675

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix

# %%
conf_mat = confusion_matrix(predictions, true_label)
score = f1_score(predictions, true_label,labels=range(len(LABELS)), average='macro')
precision = precision_score(predictions, true_label, labels=range(len(LABELS)), average='macro')

# %%
def display_confusion_matrix(cmat):
    ax = plt.gca()
    ax.matshow(cmat, cmap='Reds')
    ax.set_xticks(range(len(LABELS)))
    ax.set_xticklabels(LABELS)
    plt.setp(ax.get_xticklabels(), rotation=45, ha="left", rotation_mode="anchor")
    ax.set_yticks(range(len(LABELS)))
    ax.set_yticklabels(LABELS)
    plt.setp(ax.get_yticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    #titlestring = ""
    #if score is not None:
    #    titlestring += 'f1 = {:.3f} '.format(score)
    #if precision is not None:
    #    titlestring += '\nprecision = {:.3f} '.format(precision)
    #if recall is not None:
    #    titlestring += '\nrecall = {:.3f} '.format(recall)
    #if len(titlestring) > 0:
    #    ax.text(101, 1, titlestring, fontdict={'fontsize': 18, 'horizontalalignment':'right', 'verticalalignment':'top', 'color':'#804040'})
    plt.show()

# %%
display_confusion_matrix(conf_mat)
print(f"f1 : {score * 100} % , precision : {precision * 100} % ")
# Out:
# f1 : 11.394350958564084 % , precision : 11.53009245916579 %
